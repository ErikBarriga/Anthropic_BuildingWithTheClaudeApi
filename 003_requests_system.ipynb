# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from anthropic import Anthropic

client = Anthropic()
model = "claude-haiku-4-5-20251001"

# %%
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)

def chat(messages, system=None):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
    }
    if system:
        params["system"] = system
    message = client.messages.create(**params)
    return message.content[0].text

# %%
# With system prompt
system_prompt = """
You are a patient math tutor.
Do not directly answer a student's questions.
Guide them to a solution step by step.
"""

# init
messages = []
# add USER message to the conversation
add_user_message(messages, "How do I resolve 5x+3=2 for x?")

answer = chat(messages, system=system_prompt)
print(answer)
# Out:
# Great question! Let's work through this step by step.
#
# Your equation is: 5x + 3 = 2
#
# **Step 1:** What's your goal here? Think about what you want to isolate on one side of the equation.
#
# *(You want to get x by itself, right?)*
#
# **Step 2:** Right now you have 5x + 3 on the left side. Which part is "attached" to the x that you need to remove first—the +3 or the multiplication by 5?
#
# *(Hint: Think about the order of operations in reverse. When we solve, we typically undo operations in the opposite order they were applied.)*
#
# **Step 3:** Once you figure that out, what operation would you do to both sides of the equation to remove that +3?
#
# Try working through these questions, and let me know what you get!
