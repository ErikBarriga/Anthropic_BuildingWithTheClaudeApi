# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from anthropic import Anthropic

client = Anthropic()
model = "claude-haiku-4-5-20251001"

# %%
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)

def chat(messages, system=None, temperature=1.0):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature
    }
    
    if system:
        params["system"] = system
    
    message = client.messages.create(**params)
    return message.content[0].text

# %%
# init
messages = []
# add USER message to the conversation
add_user_message(messages, "Gemerate a one sentence movie idea")

# Low temperature - more predictable
answer = chat(messages, temperature=0.0)
print(answer)
print("--------")
# High temperature - more creative  
answer = chat(messages, temperature=1.0)

print(answer)
# Out:
# # Movie Idea
#
# A disgraced archaeologist discovers that the ancient curse she dismissed as folklore is real when her team members begin dying in impossible ways, forcing her to race against time to break the spell before it claims her life.
# --------
# # Movie Idea
#
# A cynical former astronaut is forced to train a team of eccentric civilians for a last-ditch mission to stop an asteroid, only to discover the real threat lies far deeper in space.
