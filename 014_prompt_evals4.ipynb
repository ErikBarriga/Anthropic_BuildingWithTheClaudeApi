# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
# Function to generate a new dataset
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
        "format": "json" or "python" or "regex"
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
# Generate the dataset and write it to 'dataset.json'
dataset = generate_dataset()
with open("output_PromptEvals.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
# Function to grade a test case + output using a model
def grade_by_model(test_case, output):
    eval_prompt = f"""
You are an expert AWS code reviewer. Your task is to evaluate the following AI-generated solution.

Original Task:
<task>
{test_case["task"]}
</task>

Solution to Evaluate:
<solution>
{output}
</solution>

Output Format
Provide your evaluation as a structured JSON object with the following fields, in this specific order:
- "strengths": An array of 1-3 key strengths
- "weaknesses": An array of 1-3 key areas for improvement
- "reasoning": A concise explanation of your overall assessment
- "score": A number between 1-10

Respond with JSON. Keep your response concise and direct.
Example response shape:
{{
    "strengths": string[],
    "weaknesses": string[],
    "reasoning": string,
    "score": number
}}
    """

    messages = []
    add_user_message(messages, eval_prompt)
    add_assistant_message(messages, "```json")
    eval_text = chat(messages, stop_sequences=["```"])
    return json.loads(eval_text)

# %%
# Passes a test case into Claude
def run_prompt(test_case):
    prompt = f"""
Please solve the following task:

{test_case["task"]}

* Respond only with Python, JSON, or a plain Regex
* Do not add any comments or commentary or explanation
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```code")
    output = chat(messages, stop_sequences=["```"])
    return output

# %%
# Functions to validate the output structure
import re
import ast


def validate_json(text):
    try:
        json.loads(text.strip())
        return 10
    except json.JSONDecodeError:
        return 0


def validate_python(text):
    try:
        ast.parse(text.strip())
        return 10
    except SyntaxError:
        return 0


def validate_regex(text):
    try:
        re.compile(text.strip())
        return 10
    except re.error:
        return 0


def grade_syntax(response, test_case):
    format = test_case["format"]
    if format == "json":
        return validate_json(response)
    elif format == "python":
        return validate_python(response)
    else:
        return validate_regex(response)

# %%
# Function to execute a single test case and grade the output
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)

    model_grade = grade_by_model(test_case, output)
    model_score = model_grade["score"]
    reasoning = model_grade["reasoning"]

    syntax_score = grade_syntax(output, test_case)

    score = (model_score + syntax_score) / 2

    return {
        "output": output,
        "test_case": test_case,
        "score": score,
        "reasoning": reasoning,
    }

# %%
from statistics import mean


def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []

    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)

    average_score = mean([result["score"] for result in results])
    print(f"Average score: {average_score}")

    return results

# %%
with open("output_PromptEvals.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)
# Out:
# Average score: 7.833333333333333

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "\nimport re\n\ndef parse_s3_bucket(uri):\n    match = re.match(r's3://([^/]+)/', uri)\n    return match.group(1) if match else None\n",
#     "test_case": {
#       "task": "Parse an AWS S3 bucket name from an S3 URI (s3://bucket-name/key/path) and extract just the bucket name",
#       "format": "regex"
#     },
#     "score": 8.0,
#     "reasoning": "The solution works for standard S3 URIs with key paths but has critical gaps. The regex pattern's mandatory trailing slash breaks valid single-component URIs. The lack of input type checking creates a silent failure mode. While AWS S3 URI parsing can be simplified, a production solution should either validate bucket names against AWS rules or accept that validation is caller's responsibility. The regex could be improved to make the trailing slash optional."
#   },
#   {
#     "output": "\nimport json\nimport re\n\ndef contains_wildcard_actions(policy_json_string: str) -> bool:\n    \"\"\"\n    Check if an AWS IAM policy contains any wildcard '*' actions.\n    \n    Args:\n        policy_json_string: A JSON string representing an AWS IAM policy\n        \n    Returns:\n        True if the policy contains any wildcard '*' actions, False otherwise\n    \"\"\"\n    try:\n        policy = json.loads(policy_json_string)\n    except json.JSONDecodeError:\n        return False\n    \n    statements = policy.get('Statement', [])\n    \n    for statement in statements:\n        actions = statement.get('Action', [])\n        \n        if isinstance(actions, str):\n            actions = [actions]\n        \n        if isinstance(actions, list):\n            for action in actions:\n                if isinstance(action, str) and '*' in action:\n                    return True\n    \n    return False\n",
#     "test_case": {
#       "task": "Create a Python function that takes an AWS IAM policy JSON string and returns True if it contains any wildcard '*' actions",
#       "format": "python"
#     },
#     "score": 8.0,
#     "reasoning": "The solution addresses the core requirement and handles the most common IAM policy structure well. However, it has a critical flaw in wildcard detection logic that conflates any asterisk in an action string with a true wildcard action. AWS IAM recognizes '*' as a wildcard only when it represents the entire action or specific action components (e.g., 's3:*' or '*'), not when it appears in ARN strings. Additionally, it misses the 'NotAction' field alternative, reducing its completeness for real-world policies. These issues would cause both false positives and false negatives in production use."
#   },
#   {
#     "output": "\n{\n  \"Variables\": {\n    \"DATABASE_URL\": \"postgresql://user:password@host:5432/database\",\n    \"API_KEY\": \"your-api-key-here\",\n    \"LOG_LEVEL\": \"INFO\"\n  }\n}\n",
#     "test_case": {
#       "task": "Generate a JSON object representing an AWS Lambda environment variables configuration with three variables: DATABASE_URL, API_KEY, and LOG_LEVEL",
#       "format": "json"
#     },
#     "score": 7.5,
#     "reasoning": "The solution demonstrates correct understanding of AWS Lambda environment variable JSON structure and includes all required variables. However, it violates critical AWS security best practices by including hardcoded sensitive credentials. While the format is technically valid, the content represents a significant security anti-pattern that would be problematic in production environments."
#   }
# ]
