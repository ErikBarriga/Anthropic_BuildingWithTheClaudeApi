# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from anthropic import Anthropic

client = Anthropic()
model = "claude-haiku-4-5-20251001"

# %%
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)

def chat(messages):
    message = client.messages.create(
        model=model,
        max_tokens=1000,
        messages=messages,
    )
    return message.content[0].text

# %%
# Start with an empty message list
messages = []

# Add the initial user question
add_user_message(messages, "Define quantum computing in one sentence")

# Get Claude's response
answer = chat(messages)

# Add Claude's response to the conversation history
add_assistant_message(messages, answer)

# Add a follow-up question
add_user_message(messages, "Write another sentence")

# Get the follow-up response with full context
final_answer = chat(messages)

# %%
# init
messages = []

# infinite loop to run the chatbot
while True:
    # get user input
    user_input = input("> ")
    print(">", user_input)

    # add user message to the conversation history
    add_user_message(messages, user_input)

    # get response from the chatbot
    answer = chat(messages)

    # add assistant message to the conversation
    add_assistant_message(messages, answer)

    print("---")
    print(answer)
    print("---")
# Out:
# > 2  multiplied by 3
# ---
# 2 × 3 = **6**
# ---
# > add 6 more
# ---
# 6 + 6 = **12**
# ---
# > what is a goat
# ---
# A **goat** is a domesticated farm animal with the following characteristics:
#
# - **Type**: A mammal, related to sheep
# - **Size**: Medium-sized, typically 2-3 feet tall
# - **Appearance**: Has horns (usually), a beard, and short fur in various colors
# - **Hooves**: Split hooves for climbing
# - **Uses**:
#   - Produces milk (used for cheese, yogurt)
#   - Produces meat
#   - Produces fiber (mohair, cashmere)
#   - Helps clear land by eating vegetation
#   - Kept as pets
# - **Behavior**: Intelligent, social, curious, and good climbers
# - **Diet**: Herbivores that eat grass, leaves, and plants
#
# Goats are found on farms worldwide and are known for being hardy, independent, and sometimes mischievous animals.
# ---
# > sum that last result to the previous one
# ---
# 12 + 12 = **24**
#
# (Adding the previous result of 12 to itself)
# ---
